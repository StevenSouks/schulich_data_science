# %%
from pathlib import Path

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, LassoCV, BayesianRidge
import statsmodels.formula.api as sm
import matplotlib.pylab as plt

import dmba
from dmba import regressionSummary, exhaustive_search
from dmba import backward_elimination, forward_selection, stepwise_selection
from dmba import adjusted_r2_score, AIC_score, BIC_score
# Out:
# no display found. Using non-interactive Agg backend

# %%
car_df = dmba.load_data('ToyotaCorolla.csv')
car_df = car_df.iloc[0:1000]

# %%
car_df.describe()
# Out:
#                 Id         Price    Age_08_04    Mfg_Month     Mfg_Year  \
# count  1000.000000   1000.000000  1000.000000  1000.000000  1000.000000
# mean    502.538000  11860.796000    48.034000     5.486000  2000.290000
# std     289.858781   3748.829864    16.696215     3.299195     1.383407
# min       1.000000   4350.000000     1.000000     1.000000  1999.000000
# 25%     251.750000   9450.000000    39.000000     3.000000  1999.000000
# 50%     502.500000  10900.000000    52.000000     5.000000  2000.000000
# 75%     753.250000  12950.000000    62.000000     8.000000  2001.000000
# max    1004.000000  32500.000000    68.000000    12.000000  2004.000000
#
#                   KM           HP   Met_Color    Automatic            CC  ...  \
# count    1000.000000  1000.000000  1000.00000  1000.000000   1000.000000  ...
# mean    62669.429000   102.188000     0.68300     0.048000   1590.180000  ...
# std     35414.796253    15.571484     0.46554     0.213873    492.203496  ...
# min         1.000000    69.000000     0.00000     0.000000   1300.000000  ...
# 25%     38924.000000    97.000000     0.00000     0.000000   1400.000000  ...
# 50%     58288.500000   110.000000     1.00000     0.000000   1600.000000  ...
# 75%     79446.250000   110.000000     1.00000     0.000000   1600.000000  ...
# max    243000.000000   192.000000     1.00000     1.000000  16000.000000  ...
#
#        Powered_Windows  Power_Steering        Radio   Mistlamps  Sport_Model  \
# count      1000.000000     1000.000000  1000.000000  1000.00000  1000.000000
# mean          0.614000        0.983000     0.158000     0.30600     0.288000
# std           0.487074        0.129336     0.364924     0.46106     0.453058
# min           0.000000        0.000000     0.000000     0.00000     0.000000
# 25%           0.000000        1.000000     0.000000     0.00000     0.000000
# 50%           1.000000        1.000000     0.000000     0.00000     0.000000
# 75%           1.000000        1.000000     0.000000     1.00000     1.000000
# max           1.000000        1.000000     1.000000     1.00000     1.000000
#
#        Backseat_Divider  Metallic_Rim  Radio_cassette  Parking_Assistant  \
# count       1000.000000   1000.000000     1000.000000        1000.000000
# mean           0.798000      0.224000        0.157000           0.004000
# std            0.401693      0.417131        0.363983           0.063151
# min            0.000000      0.000000        0.000000           0.000000
# 25%            1.000000      0.000000        0.000000           0.000000
# 50%            1.000000      0.000000        0.000000           0.000000
# 75%            1.000000      0.000000        0.000000           0.000000
# max            1.000000      1.000000        1.000000           1.000000
#
#            Tow_Bar
# count  1000.000000
# mean      0.245000
# std       0.430302
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000
#
# [8 rows x 36 columns]

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 1000 non-null   int64
#  1   Model              1000 non-null   object
#  2   Price              1000 non-null   int64
#  3   Age_08_04          1000 non-null   int64
#  4   Mfg_Month          1000 non-null   int64
#  5   Mfg_Year           1000 non-null   int64
#  6   KM                 1000 non-null   int64
#  7   Fuel_Type          1000 non-null   object
#  8   HP                 1000 non-null   int64
#  9   Met_Color          1000 non-null   int64
#  10  Color              1000 non-null   object
#  11  Automatic          1000 non-null   int64
#  12  CC                 1000 non-null   int64
#  13  Doors              1000 non-null   int64
#  14  Cylinders          1000 non-null   int64
#  15  Gears              1000 non-null   int64
#  16  Quarterly_Tax      1000 non-null   int64
#  17  Weight             1000 non-null   int64
#  18  Mfr_Guarantee      1000 non-null   int64
#  19  BOVAG_Guarantee    1000 non-null   int64
#  20  Guarantee_Period   1000 non-null   int64
#  21  ABS                1000 non-null   int64
#  22  Airbag_1           1000 non-null   int64
#  23  Airbag_2           1000 non-null   int64
#  24  Airco              1000 non-null   int64
#  25  Automatic_airco    1000 non-null   int64
#  26  Boardcomputer      1000 non-null   int64
#  27  CD_Player          1000 non-null   int64
#  28  Central_Lock       1000 non-null   int64
#  29  Powered_Windows    1000 non-null   int64
#  30  Power_Steering     1000 non-null   int64
#  31  Radio              1000 non-null   int64
#  32  Mistlamps          1000 non-null   int64
#  33  Sport_Model        1000 non-null   int64
#  34  Backseat_Divider   1000 non-null   int64
#  35  Metallic_Rim       1000 non-null   int64
#  36  Radio_cassette     1000 non-null   int64
#  37  Parking_Assistant  1000 non-null   int64
#  38  Tow_Bar            1000 non-null   int64
# dtypes: int64(36), object(3)
# memory usage: 304.8+ KB

# %%
predictors = ['Age_08_04', 'KM', 'HP', 'Met_Color', 'Automatic', 'CC', 'Doors', 'Quarterly_Tax', 'Weight']
outcome = 'Price'

#One-Hot-Encoding to obtain dummy variables
X = pd.get_dummies(car_df[predictors], drop_first=True)
y = car_df[outcome]
train_X, valid_X, train_y, valid_y = train_test_split(X,y, test_size=0.4, random_state=1)

car_lm = LinearRegression()
car_lm.fit(train_X, train_y)

print('intercept ', car_lm.intercept_)
print(pd.DataFrame({'Predictor': X.columns, 'coefficient': car_lm.coef_}))
# Out:
# intercept  2237.1286350864284
#        Predictor  coefficient
# 0      Age_08_04  -140.024285
# 1             KM    -0.020691
# 2             HP    41.095039
# 3      Met_Color    55.563729
# 4      Automatic   437.920023
# 5             CC     0.005057
# 6          Doors   -22.436326
# 7  Quarterly_Tax     6.942553
# 8         Weight    11.854104

# %%
#prints regression statistics for standard errors 
regressionSummary(train_y, car_lm.predict(train_X))
# Out:
# Regression statistics
#
#                       Mean Error (ME) : -0.0000
#        Root Mean Squared Error (RMSE) : 1426.6036
#             Mean Absolute Error (MAE) : 1070.0948
#           Mean Percentage Error (MPE) : -1.0984
# Mean Absolute Percentage Error (MAPE) : 9.5823

# %%
#Create r statistics
pred_y = car_lm.predict(train_X)

#Making predictions on a new set
car_lm_pred = car_lm.predict(valid_X)
