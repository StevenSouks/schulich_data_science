# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/delinai/schulich_ds1_2024/main/Datasets/Assignment1_StreamFlow_Subscription_Data.csv')

# %%
df.head()
# Out:
#    User_ID  Age  Gender Location    Subscription_Start_Date Subscription_Type  \
# 0        1   56   Other  Central 2020-06-07 01:53:37.656934           Premium
# 1        2   69   Other     West 2024-02-21 01:53:37.656980          Standard
# 2        3   46  Female    North 2022-10-06 01:53:37.656995          Standard
# 3        4   32  Female     East 2022-01-04 01:53:37.657006          Standard
# 4        5   60  Female    North 2020-03-13 01:53:37.657017          Standard
#
#    Monthly_Payment Payment_Method  Monthly_Hours_Watched Favorite_Genre  \
# 0            19.99    Credit Card              31.513153         Action
# 1            14.99    Credit Card               4.982277          Drama
# 2            14.99         PayPal               4.114953         Sci-Fi
# 3            14.99    Credit Card              60.244820         Action
# 4            14.99    Credit Card               4.711855         Sci-Fi
#
# ...

# %%
df.describe()
# Out:
#            User_ID          Age        Subscription_Start_Date  \
# count  1000.000000  1000.000000                           1000
# mean    500.500000    44.385000  2021-09-18 17:08:01.662466560
# min       1.000000    18.000000     2019-05-10 01:53:37.659073
# 25%     250.750000    31.750000  2020-05-15 19:53:37.664891136
# 50%     500.500000    45.000000  2021-08-21 01:53:37.662536448
# 75%     750.250000    57.000000  2023-01-09 07:53:37.664328192
# max    1000.000000    70.000000     2024-05-06 01:53:37.662112
# std     288.819436    15.321669                            NaN
#
#        Monthly_Payment  Monthly_Hours_Watched  Average_Session_Length  \
# count      1000.000000            1000.000000             1000.000000
# mean         14.580000              19.071653                1.893771
# min           9.990000               0.041574                0.000486
# 25%           9.990000               5.490739                0.548918
# ...

# %%
#Converting Sub Start Date as Date/Time
df['Subscription_Start_Date'] = pd.to_datetime(df['Subscription_Start_Date'])

#Creating a year and quarter column
df['year'] = df['Subscription_Start_Date'].dt.year
df['quarter'] = df['Subscription_Start_Date'].dt.quarter

# Create a 'year_quarter' column for grouping
df['year_quarter'] = df['year'].astype(str) + ' Q' + df['quarter'].astype(str)


print(df[['Subscription_Start_Date','year', 'quarter', 'year_quarter']].head())
# Out:
#      Subscription_Start_Date  year  quarter year_quarter
# 0 2020-06-07 01:53:37.656934  2020        2      2020 Q2
# 1 2024-02-21 01:53:37.656980  2024        1      2024 Q1
# 2 2022-10-06 01:53:37.656995  2022        4      2022 Q4
# 3 2022-01-04 01:53:37.657006  2022        1      2022 Q1
# 4 2020-03-13 01:53:37.657017  2020        1      2020 Q1

# %%
df['Age'].describe()
# Out:
# count    1000.000000
# mean       44.385000
# std        15.321669
# min        18.000000
# 25%        31.750000
# 50%        45.000000
# 75%        57.000000
# max        70.000000
# Name: Age, dtype: float64

# %%
df.head()
# Out:
#    User_ID  Age  Gender Location     Subscription_Start_Date  \
# 0        1   56   Other  Central  2020-06-07 01:53:37.656934
# 1        2   69   Other     West  2024-02-21 01:53:37.656980
# 2        3   46  Female    North  2022-10-06 01:53:37.656995
# 3        4   32  Female     East  2022-01-04 01:53:37.657006
# 4        5   60  Female    North  2020-03-13 01:53:37.657017
#
#   Subscription_Type  Monthly_Payment Payment_Method  Monthly_Hours_Watched  \
# 0           Premium            19.99    Credit Card              31.513153
# 1          Standard            14.99    Credit Card               4.982277
# 2          Standard            14.99         PayPal               4.114953
# 3          Standard            14.99    Credit Card              60.244820
# 4          Standard            14.99    Credit Card               4.711855
#
#   Favorite_Genre Devices_Used  Average_Session_Length  Content_ID  \
# 0         Action           PC                1.195762        1023
# ...

# %%
df['Churned'].describe()
# Out:
# count    1000.000000
# mean        0.246000
# std         0.430894
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Churned, dtype: float64

# %%
#Isolate churnned sample size
churned_df = df[df['Churned'] == 1]

# %%
#Churn is produced on average by 43 year olds
churned_df.describe()
# Out:
#           User_ID         Age  Monthly_Payment  Monthly_Hours_Watched  \
# count  246.000000  246.000000       246.000000             246.000000
# mean   505.361789   43.174797        14.502195              17.039672
# std    284.676765   15.507139         3.494289              17.236483
# min     13.000000   18.000000         9.990000               0.041574
# 25%    273.250000   30.000000         9.990000               5.105890
# 50%    501.500000   41.000000        14.990000              11.948593
# 75%    752.250000   56.000000        14.990000              23.618435
# max    999.000000   70.000000        19.990000             108.122364
#
#        Average_Session_Length   Content_ID  Rating_Given  Churned
# count              246.000000   246.000000    246.000000    246.0
# mean                 1.920114  1050.443089      2.593496      1.0
# std                  1.841691    30.536877      1.273513      0.0
# min                  0.000821  1000.000000      1.000000      1.0
# ...

# %%
churned_df.value_counts()
# Out:
# User_ID  Age  Gender  Location  Subscription_Start_Date     Subscription_Type  Monthly_Payment  Payment_Method  Monthly_Hours_Watched  Favorite_Genre  Devices_Used  Average_Session_Length  Content_ID  Rating_Given  Churned  Date_of_Churn               Reason_for_Churn
# 13       41   Other   North     2021-04-22 01:53:37.657108  Standard           14.99            Direct Debit    14.011035              Sci-Fi          Mobile        0.152133                1059        5             1        2021-06-13 01:53:37.657108  Found better service         1
# 621      52   Other   East      2021-04-26 01:53:37.663824  Standard           14.99            Direct Debit    14.231740              Action          Mobile        0.178973                1080        3             1        2022-02-22 01:53:37.663824  Dissatisfied with content    1
# ...

# %%
df['Reason_for_Churn'].value_counts()
# Out:
# Reason_for_Churn
# Price increase               68
# Found better service         64
# Personal reasons             62
# Dissatisfied with content    52
# Name: count, dtype: int64

# %%
#find how many from each subscription type who churned.
df['Churned'].value_counts()
# Out:
# Churned
# 0    754
# 1    246
# Name: count, dtype: int64

# %%
churned_df['Subscription_Type'].value_counts()
# Out:
# Subscription_Type
# Standard    124
# Basic        73
# Premium      49
# Name: count, dtype: int64

# %%
#Isolate continuing users

c_users = df[df['Churned'] == 0]

# %%
c_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 754 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   User_ID                  754 non-null    int64
#  1   Age                      754 non-null    int64
#  2   Gender                   754 non-null    object
#  3   Location                 754 non-null    object
#  4   Subscription_Start_Date  754 non-null    object
#  5   Subscription_Type        754 non-null    object
#  6   Monthly_Payment          754 non-null    float64
#  7   Payment_Method           754 non-null    object
#  8   Monthly_Hours_Watched    754 non-null    float64
#  9   Favorite_Genre           754 non-null    object
#  10  Devices_Used             754 non-null    object
#  11  Average_Session_Length   754 non-null    float64
#  12  Content_ID               754 non-null    int64
#  13  Rating_Given             754 non-null    int64
# ...

# %%
c_users.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df['Favorite_Genre'].value_counts().reset_index()
# Out:
#   Favorite_Genre  count
# 0          Drama    212
# 1         Action    205
# 2         Comedy    203
# 3         Sci-Fi    192
# 4    Documentary    188

# %%
#Calculating Churn Rate
def churn_rate(group):
    churned = group['Churned'].sum()
    total = group['Churned'].count()
    return (churned/total) * 100

# %%
print(df['Churned'].unique())
# Out:
# [0 1]

# %%
df['Subscription_Start_Date'].describe()
# Out:
# count                           1000
# unique                          1000
# top       2020-06-07 01:53:37.656934
# freq                               1
# Name: Subscription_Start_Date, dtype: object

# %%
#Find Churn Rate for Standard Users
